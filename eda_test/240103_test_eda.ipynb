# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../../../estsoft/data/example_test_files/test.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12480 entries, 0 to 12479
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               12480 non-null  int64
#  1   is_business          12480 non-null  int64
#  2   product_type         12480 non-null  int64
#  3   is_consumption       12480 non-null  int64
#  4   prediction_datetime  12480 non-null  object
#  5   data_block_id        12480 non-null  int64
#  6   row_id               12480 non-null  int64
#  7   prediction_unit_id   12480 non-null  int64
#  8   currently_scored     12480 non-null  bool
# dtypes: bool(1), int64(7), object(1)
# memory usage: 792.3+ KB

# %%
df.describe()
# Out:
#              county   is_business  product_type  is_consumption  \
# count  12480.000000  12480.000000  12480.000000     12480.00000
# mean       7.276923      0.553846      1.876923         0.50000
# std        4.875589      0.497112      1.102596         0.50002
# min        0.000000      0.000000      0.000000         0.00000
# 25%        3.000000      0.000000      1.000000         0.00000
# 50%        7.000000      1.000000      2.000000         0.50000
# 75%       11.000000      1.000000      3.000000         1.00000
# max       15.000000      1.000000      3.000000         1.00000
#
#        data_block_id        row_id  prediction_unit_id
# count   12480.000000  1.248000e+04        12480.000000
# mean      635.500000  2.012112e+06           33.661538
# std         1.118079  3.602810e+03           20.374462
# min       634.000000  2.005872e+06            0.000000
# 25%       634.750000  2.008992e+06           16.000000
# 50%       635.500000  2.012112e+06           33.000000
# 75%       636.250000  2.015231e+06           52.000000
# max       637.000000  2.018351e+06           68.000000

# %%
df.isnull().sum()
# Out:
# county                 0
# is_business            0
# product_type           0
# is_consumption         0
# prediction_datetime    0
# data_block_id          0
# row_id                 0
# prediction_unit_id     0
# currently_scored       0
# dtype: int64

# %%
df['data_block_id'].value_counts()
# Out:
# data_block_id
# 634    3120
# 635    3120
# 636    3120
# 637    3120
# Name: count, dtype: int64

# %%
df['prediction_unit_id'].value_counts()
# Out:
# prediction_unit_id
# 0     192
# 30    192
# 32    192
# 33    192
# 34    192
#      ...
# 23    192
# 24    192
# 25    192
# 27    192
# 60    192
# Name: count, Length: 65, dtype: int64

# %%
plt.pie(df['is_business'].value_counts(), labels=df['is_business'].unique(), autopct='%.2f%%')
plt.title('is business')
plt.legend()

# %%
plt.pie(df['is_consumption'].value_counts(), labels=df['is_consumption'].unique(), autopct='%.2f%%')
plt.title('is consumption')
plt.legend()

# %%
plt.pie(df['product_type'].value_counts(), labels=df['product_type'].unique(), autopct='%.2f%%')
plt.title('product type')
plt.legend()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='prediction_unit_id', data=df)
plt.title('county')
# Out:
# Text(0.5, 1.0, 'county')

# %%
sns.countplot(x='county', data=df)
plt.title('county')
# Out:
# Text(0.5, 1.0, 'county')

# %%
df.columns
# Out:
# Index(['county', 'is_business', 'product_type', 'is_consumption',
#        'prediction_datetime', 'data_block_id', 'row_id', 'prediction_unit_id',
#        'currently_scored'],
#       dtype='object')

# %%
df.prediction_datetime.unique()
# Out:
# array(['2023-05-28 00:00:00', '2023-05-28 01:00:00',
#        '2023-05-28 02:00:00', '2023-05-28 03:00:00',
#        '2023-05-28 04:00:00', '2023-05-28 05:00:00',
#        '2023-05-28 06:00:00', '2023-05-28 07:00:00',
#        '2023-05-28 08:00:00', '2023-05-28 09:00:00',
#        '2023-05-28 10:00:00', '2023-05-28 11:00:00',
#        '2023-05-28 12:00:00', '2023-05-28 13:00:00',
#        '2023-05-28 14:00:00', '2023-05-28 15:00:00',
#        '2023-05-28 16:00:00', '2023-05-28 17:00:00',
#        '2023-05-28 18:00:00', '2023-05-28 19:00:00',
#        '2023-05-28 20:00:00', '2023-05-28 21:00:00',
#        '2023-05-28 22:00:00', '2023-05-28 23:00:00',
#        '2023-05-29 00:00:00', '2023-05-29 01:00:00',
#        '2023-05-29 02:00:00', '2023-05-29 03:00:00',
#        '2023-05-29 04:00:00', '2023-05-29 05:00:00',
#        '2023-05-29 06:00:00', '2023-05-29 07:00:00',
#        '2023-05-29 08:00:00', '2023-05-29 09:00:00',
#        '2023-05-29 10:00:00', '2023-05-29 11:00:00',
#        '2023-05-29 12:00:00', '2023-05-29 13:00:00',
#        '2023-05-29 14:00:00', '2023-05-29 15:00:00',
#        '2023-05-29 16:00:00', '2023-05-29 17:00:00',
#        '2023-05-29 18:00:00', '2023-05-29 19:00:00',
#        '2023-05-29 20:00:00', '2023-05-29 21:00:00',
#        '2023-05-29 22:00:00', '2023-05-29 23:00:00',
#        '2023-05-30 00:00:00', '2023-05-30 01:00:00',
#        '2023-05-30 02:00:00', '2023-05-30 03:00:00',
#        '2023-05-30 04:00:00', '2023-05-30 05:00:00',
#        '2023-05-30 06:00:00', '2023-05-30 07:00:00',
#        '2023-05-30 08:00:00', '2023-05-30 09:00:00',
#        '2023-05-30 10:00:00', '2023-05-30 11:00:00',
#        '2023-05-30 12:00:00', '2023-05-30 13:00:00',
#        '2023-05-30 14:00:00', '2023-05-30 15:00:00',
#        '2023-05-30 16:00:00', '2023-05-30 17:00:00',
#        '2023-05-30 18:00:00', '2023-05-30 19:00:00',
#        '2023-05-30 20:00:00', '2023-05-30 21:00:00',
#        '2023-05-30 22:00:00', '2023-05-30 23:00:00',
#        '2023-05-31 00:00:00', '2023-05-31 01:00:00',
#        '2023-05-31 02:00:00', '2023-05-31 03:00:00',
#        '2023-05-31 04:00:00', '2023-05-31 05:00:00',
#        '2023-05-31 06:00:00', '2023-05-31 07:00:00',
#        '2023-05-31 08:00:00', '2023-05-31 09:00:00',
#        '2023-05-31 10:00:00', '2023-05-31 11:00:00',
#        '2023-05-31 12:00:00', '2023-05-31 13:00:00',
#        '2023-05-31 14:00:00', '2023-05-31 15:00:00',
#        '2023-05-31 16:00:00', '2023-05-31 17:00:00',
#        '2023-05-31 18:00:00', '2023-05-31 19:00:00',
#        '2023-05-31 20:00:00', '2023-05-31 21:00:00',
#        '2023-05-31 22:00:00', '2023-05-31 23:00:00'], dtype=object)
